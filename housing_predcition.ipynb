# %%
import pandas as pd

# %%
#load the dataset
dataframe=pd.read_csv("housing.csv")

# %%
dataframe.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataframe.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#so here the total bedrooms are misssing.

# %%
dataframe.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
#split the data
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(dataframe, test_size=0.2, random_state=42)
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %%
#now after splitting we can drop the label set since its not necesaary to clean up the label part
housing=train_set.drop("median_house_value",axis=1)
labels=train_set["median_house_value"].copy()

# %%
#now that we have split the data,we next need to clean the data
#handling the numerical values
from sklearn.impute import SimpleImputer
imputer =SimpleImputer(strategy="mean")
housing_num = housing.drop("ocean_proximity", axis=1)
X_new=imputer.fit_transform(housing_num)
X=pd.DataFrame(X_new,columns=housing_num.columns)
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -117.03     32.71                33.0       3126.0           627.0
# 1        -118.16     33.77                49.0       3382.0           787.0
# 2        -120.48     34.66                 4.0       1897.0           331.0
# 3        -117.11     32.69                36.0       1421.0           367.0
# 4        -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 16507    -117.96     33.78                35.0       1330.0           201.0
# 16508    -117.43     34.02                33.0       3084.0           570.0
# 16509    -118.38     34.03                36.0       2101.0           569.0
# 16510    -121.96     37.58                15.0       3575.0           597.0
# 16511    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income
# ...

# %%
X.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.582290     35.643149           28.608285   2642.004784
# std        2.005654      2.136665           12.602499   2174.646744
# min     -124.350000     32.550000            1.000000      2.000000
# 25%     -121.810000     33.930000           18.000000   1454.000000
# 50%     -118.510000     34.260000           29.000000   2129.000000
# 75%     -118.010000     37.720000           37.000000   3160.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    16512.000000  16512.000000  16512.000000   16512.000000
# mean       538.496851   1426.453004    499.986919       3.880754
# std        419.007096   1137.056380    380.967964       1.904294
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#see the values are now filled.now time to fill the categorical values
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
housing_cat=housing[["ocean_proximity"]]

# %%
housing_cat_encoded = ohe.fit_transform(housing_cat)
housing_cat_encoded[:10]
# Out:
# <10x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>

# %%
#we are done with cleaning of the data.
#here you can add pipelines for easy management(pg.no.101)
#you need to use the pipelines now to merge all the data
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
num_pipeline = Pipeline([
 ('imputer', SimpleImputer(strategy="median")),
 ('std_scaler', StandardScaler()),
 ])
housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
from sklearn.compose import ColumnTransformer
num_attribs = list(housing_num)
cat_attribs = ["ocean_proximity"]
full_pipeline = ColumnTransformer([
 ("num", num_pipeline, num_attribs),
 ("cat", OneHotEncoder(), cat_attribs),
 ])
housing_prepared = full_pipeline.fit_transform(housing)

# %%
#now you can train the model since the data is almost cleaned
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
reg.fit(housing_prepared,labels)
# Out:
# RandomForestRegressor()

# %%
# import numpy as np
from sklearn.model_selection import cross_val_score
scores = cross_val_score(reg, housing_prepared, labels,
 scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
scores
# Out:
# array([-2.18565419e+09, -2.58205971e+09, -2.25476884e+09, -2.54568372e+09,
#        -2.54347367e+09, -2.18791840e+09, -2.09059069e+09, -2.60696966e+09,
#        -2.45484370e+09, -2.51603910e+09])

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
display_scores(tree_rmse_scores)
# Out:
# Scores: [46750.98061481 50813.97159925 47484.40628814 50454.76902786
#  50432.86295397 46775.19002194 45722.97772887 51058.49250739
#  49546.37930124 50160.13459956]
# Mean: 48920.01646430117
# Standard deviation: 1905.8218543056332

# %%
from sklearn.metrics import mean_squared_error
X_test = test_set.drop("median_house_value", axis=1)
y_test = test_set["median_house_value"].copy()
X_test_prepared = full_pipeline.transform(X_test)
final_predictions = reg.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 48939.92292761163
